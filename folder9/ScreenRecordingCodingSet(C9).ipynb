# %% [markdown]
# <a href="https://colab.research.google.com/github/BrandonHill0927/Intro_To_Python/blob/main/ScreenRecordingCodingSet(C9).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chapter **9** Coding Set
#
# **Remember to save a copy of this template BEFORE YOU START WORKING :)**
#
# Work completed by [Brandon Hill].
#
# IMPORTANT: Remember to screen record ALL of your work on at least one problem. You must turn off the generative AI code-completion for this problem, as this problem is preparation for our final exam practical. You can turn off generative AI code-completion within Colab by tapping/clicking the settings icon in the upper right, tapping/clicking the AI Assistance section, and then deselecting "Consented to use generative AI features" and selecting "Hide generative AI features" (these settings may be returned to their previous states once you've completed this problem).
#
# If you start to struggle with a problem for an extended period of time, remember you can go comment on two other submissions now (seeing other student work helps), or you can post in our discussion forum for questions, which can also earn you extra credit.

# %% [markdown]
# ## Imports
#
# **If your program requires additional modules, external resources, or files, use this cell to set them up**

# %%
# configure your environment

# you can uncomment this code to make use of files stored in your Google Drive
# from google.colab import drive
# drive.mount('/content/drive')

# you can uncomment the following line of code to use the pandas library
# import pandas as pd

# %% [markdown]
# ## Programming Exercises

# %% [markdown]
# ### Problem **7**
#
# #### Question Text
#
# In this chapter’s source code folder (available on the Computer Science Portal at www. pearsonhighered.com/gaddis), you will find a text file named . This file contains a chronological list of the World Series’ winning teams from 1903 through 2009. The first line in the file is the name of the team that won in 1903, and the last line is the name of the team that won in 2009. (Note the World Series was not played in 1904 or 1994. There are entries in the file indicating this.)
#
# Write a program that reads this file and creates a dictionary in which the keys are the names of the teams, and each key’s associated value is the number of times the team has won the World Series.
#
#  The program should also create a dictionary in which the keys are the years, and each key’s associated value is the name of the team that won that year.The program should prompt the user for a year in the range of 1903 through 2009. It should then display the name of the team that won the World Series that year, and the number of times that team has won the World Series.
#
# #### High-Level Overview
#
# *In two to three sentences at minimum, walk through your general approach to the problem and identify any particular issues you had.*

# %%
# I begin with creating constants for the program 
# first for the min year 
minyear=1903
# next for the max year 
maxyear=2009
# I then create dictionaries to be used by the program later 
# first to track each each teams win 
winsbyteam= {}
# then to keep track of winning teams by year 
winnerbyyear= {}
# I then open the file needed for the program 
worldseriesfile= open('WorldSeriesWinners.txt', 'r')
# I then ensure that the program starts with the year 1903
year=minyear
# I then create begin creating a loop to read the file 
for line in worldseriesfile:
    team = line.strip()
    if team == '':
        continue 
    winnerbyyear[year]= team 
    if team != 'World Series Not Played':
        if team in winsbyteam: 
            winsbyteam[team] += 1 
        else: 
            winsbyteam[team] = 1
    year +=1 
# close file 
worldseriesfile.close()
# This is where I get the user inpuy year 
useryear = int(input("Enter a year betweem 1903 and 2009."))
# i begin to validate if the user year is in range 
if useryear <minyear or useryear >maxyear:
    print("Year must be between 1903-2009")
else: 
    winner = winnerbyyear[useryear] 
    if winner== "World Series Not PLayed":
        print(f"The world series was not played in, {useryear}")
    else: 
        timeswon=winsbyteam[winner]
        print(f"In, {useryear}, the, {winner}," "won the world series")
        print(f"The, {winner}, have won the world series, {timeswon}, of times")
# Out:
# In, 2002, the, Anaheim Angels,won the world series
# The, Anaheim Angels, have won the world series, 1, of times

# %% [markdown]
# ### Problem **?**
#
# #### Question Text
#
# *Paste in the question text below.*
#
# #### High-Level Overview
#
# *In two to three sentences at minimum, walk through your general approach to the problem and identify any particular issues you had.*

# %%
# add your code to this cell
# remember to include comments like this one for most of your code
# remember to "Run cell" once you're done, excecuting your code so the output is displayed below

# %% [markdown]
# ## Helpful Checks
#
# 1.   Did you comment every line of code with meaningful information that will help others reading your code?
# 2.   Did you use appropriate names for your variables, functions, and/or classes?
# 3.   Did you include a high-level explanation for each solution?
# 4.   Did you run each cell that includes a final solution so the output is saved and easily viewed by others?
# 5.   Are you sharing an editable link (i.e., Share > Anyone with the link > Editor) if using Colaboratory, or did you make more than ten commits if using GitHub?
# 6.   Did you remember to comment on the submissions of two other students?
# 7.   Did you remember to screen record all of your work for at least one problem while turning off the generative AI features?
# 8.   Did you remember to create a diagram (e.g., UML class diagram, flowchart, or hierarchical diagram) and include the link with your D2L submission?
